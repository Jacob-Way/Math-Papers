# %% [markdown]
# ## Title

# %%
from matplotlib import pyplot as plt;
import random as rand;
import numpy as np;
n = np.random.normal(0,1,100);
w = np.cumsum(n);
plt.plot(range(100),w);

# %% [markdown]
# This is a random walk with normal distribution with variance 1
